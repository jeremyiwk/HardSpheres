# %%
# P = 2 sum v i / 4 L T

# PV/NKT = 1 - N/2V (-4/3 pi (2 r0)^3 )

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pressure = np.loadtxt("../src/pressure.dat")

vx = np.loadtxt("../src/velocity_traj_x.dat")
vy = np.loadtxt("../src/velocity_traj_y.dat")

# %%
plt.plot(pressure);

# %%
N_p = 50
time_steps = 5000
dt = 0.01
P = 2*np.sum(pressure)/(4*2*time_steps*dt)
P
# Out:
# 4.1422084555000005

# %%
NKT = ((1/2)*(vx**2 + vy**2)).sum(axis=-1)

# %%
c = 4*P/NKT

# %%
c[0]
# Out:
# 1.0002359389729762
